# %% [markdown]
# Connected to Python 3.14.0

# %%
def add_number():
    "sum 2 numbers"
    x=  7
    y = 35
    return x,y, x+y

add_number()
type(add_number)
type(add_number())
# Out:
# tuple

# %%
def add_number():
    "sum 2 numbers"
    x=  7
    y = 35
    return x,y, x+y

print(add_number())
type(add_number)
type(add_number())
# Out:
# (7, 35, 42)
# tuple

# %%
def add_number(x, y):
    "sum 2 numbers"
    return x,y, x+y

print(add_number(3,5))
type(add_number)
type(add_number())
# Out:
# (3, 5, 8)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 9
#       7 print(add_number(3,5))
#       8 type(add_number)
# ----> 9 type(add_number())
#
# TypeError: add_number() missing 2 required positional arguments: 'x' and 'y'

# %%
def add_number(x, y):
    "sum 2 numbers"
    return x,y, x+y

print(add_number(3,5))
# type(add_number)
# type(add_number())
# Out:
# (3, 5, 8)

# %%
def add_number(x, y):
    "sum 2 numbers"
    return x,y, x+y

print(add_number(3,5))
type(add_number)
type(add_number(3,4.5))
# Out:
# (3, 5, 8)
# tuple

# %%
def add_number(x, y):
    "sum 2 numbers"
    return x,y, x+y

print(add_number(3,5.0))
type(add_number)
type(add_number(3,4.5))
# Out:
# (3, 5.0, 8.0)
# tuple

# %%
def add_number(x, y):
    "sum 2 numbers"
    return x,y, x+y

print(add_number("3","5.0"))
type(add_number)
type(add_number(3,4.5))
# Out:
# ('3', '5.0', '35.0')
# tuple

# %%
def add_numbers(n1=100, n2=1000):
    sum = n1+n2
    return sum

result = add_number(5.4)
print(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 7
#       4     sum = n1+n2
#       5     return sum
# ----> 7 result = add_number(5.4)
#       8 print(result)
#
# TypeError: add_number() missing 1 required positional argument: 'y'

# %%
def add_numbers(n1=100, n2=1000):
    sum = n1+n2
    return sum

result = add_number(5.4)
print(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 6
#       3     sum = n1+n2
#       4     return sum
# ----> 6 result = add_number(5.4)
#       7 print(result)
#
# TypeError: add_number() missing 1 required positional argument: 'y'

# %%
def add_numbers(n1=100, n2=1000):
    sum = n1+n2
    return sum

result = add_numbers(5.4)
print(result)
# Out:
# 1005.4

# %%
def foor(*args):
    print(args)

foo(1,2,3,4,5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 5
#       2 def foor(*args):
#       3     print(args)
# ----> 5 foo(1,2,3,4,5)
#
# NameError: name 'foo' is not defined

# %%
def foo(*args):
    print(args)

foo(1,2,3,4,5)
# Out:
# (1, 2, 3, 4, 5)

# %%
def my_sum(*integers):
    result=0
    for x in integers:
        result += x
        return result
    
my_sum(1,2,3)
# Out:
# 1

# %%
def my_sum(*integers):
    result=0
    for x in integers:
        result += x
        return result
    
my_sum(1,2,3,4)
# Out:
# 1

# %%
def my_sum(*integers):
    result=0
    for x in integers:
        result += x
        return result
    
print(my_sum(1,2,3,4))
# Out:
# 1

# %%
def my_sum(*integers):
    result=0
    for x in integers:
        result += x
    return result
    
print(my_sum(1,2,3,4))
# Out:
# 10

# %%
def my_functions(**Patient):
    print("Her last name is "+ Patient["lname"])
    print(type(Patient))

my_functions(fanme = "Maya", lname = "Malmud")
# Out:
# Her last name is Malmud
# <class 'dict'>

# %%
def decoratorTal(func):

    def wrapper():
        print("Before calling the function.")
        func()
        print("After calling the function.")
    return wrapper

@decoratorTal
def greet():
    print("Hello, World1")

# %%
def decoratorTal(func):

    def wrapper():
        print("Before calling the function.")
        func()
        print("After calling the function.")
    return wrapper

@decoratorTal
def greet():
    print("Hello, World1")

# %%
def decorator(func):

    def wrapper():
        print("Before calling the function.")
        func()
        print("After calling the function.")
    return wrapper

@decorator
def greet():
    print("Hello, World1")

# %%
def decoratorTal(func):

    def wrapper():
        print("Before calling the function.")
        func()
        print("After calling the function.")
    return wrapper

@decoratorTal
def greet():
    print("Hello, World1")

greet()
# Out:
# Before calling the function.
# Hello, World1
# After calling the function.

# %% [markdown]
# No kernel connected
