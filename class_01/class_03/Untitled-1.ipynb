# %%
patientId = ['001222', '001422', '001224', '001223']
illness = ['Diabetes', 'Hypertension', 'Asthma', 'Allergy']
for q, a in zip(patientId, illness):
    print('The patient id:', q, 'has illness:', a)
# Out:
# The patient id: 001222 has illness: Diabetes
# The patient id: 001422 has illness: Hypertension
# The patient id: 001224 has illness: Asthma
# The patient id: 001223 has illness: Allergy
